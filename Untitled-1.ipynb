# %%
import pandas as pd

# Path to your file
file_path = r"/workspaces/AdiFiles/D_cba_reg.txt"

try:
    # Read the file into a DataFrame
    df = pd.read_csv(file_path, delimiter='\t')  # Assuming tab-delimited data, adjust delimiter if necessary
    
    # Display the DataFrame
    print(df)
except Exception as e:
    print("An error occurred:", e)
# Out:
#                                                 impact            AT  \
# 0                                          Value Added  4.029981e+05
# 1                                           Employment  8.465534e+03
# 2                                      Employment hour  1.567646e+10
# 3    GHG emissions (GWP100) | Problem oriented appr...  1.186026e+11
# 4    Human toxicity (USEtox) | USEtox2008 | CTUh (R...  5.475518e+04
# ..                                                 ...           ...
# 121           Unused Domestic Extraction - Oil and Gas  2.722333e+03
# 122  Unused Domestic Extraction - Non-metalic Minerals  1.490935e+04
# 123              Unused Domestic Extraction - Iron Ore  4.314875e+03
# 124  Unused Domestic Extraction - Non-ferous metal ...  9.239941e+03
# 125                     Land use Crop, Forest, Pasture  1.263069e+05
#
#                BE            BG            CY            CZ            DE  \
# ...
